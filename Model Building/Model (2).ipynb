# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/weather_data_preprocessed.csv")

# %%
df.head(20)
# Out:
#           date  rain_or_not     pressure  avg_temperature   humidity  \
# 0   2023-01-01            1   992.965681        23.745401  46.140905
# 1   2023-01-02            1  1037.273025        30.030503  59.876587
# 2   2023-01-03            1  1034.193357        28.365224  51.464618
# 3   2023-01-04            1   968.610142        27.550929  53.103799
# 4   2023-01-05            1  1030.264331        23.639303  57.826186
# 5   2023-01-06            1   995.818689        24.148136  49.703435
# 6   2023-01-07            1   998.296887        23.671006  63.997418
# 7   2023-01-08            1   963.347997        32.245441  67.083073
# 8   2023-01-09            1   958.060151        30.078517  64.088581
# 9   2023-01-10            1  1022.793931        31.620631  71.876470
# 10  2023-01-11            1   999.646115        25.205845  58.365841
# 11  2023-01-12            1   993.685070        35.000000  75.557750
# 12  2023-01-13            0  1022.950823        25.983840  55.041385
# 13  2023-01-14            1  1026.551290        28.416595  62.480013
# 14  2023-01-15            1   965.890817        28.509556  68.886958
# 15  2023-01-16            1  1011.022515        25.983840  55.041385
# 16  2023-01-17            0   963.535408        25.983840  55.041385
# 17  2023-01-18            1  1025.137509        33.019024  68.651421
# 18  2023-01-19            1  1015.695516        32.409620  67.795797
# 19  2023-01-20            1  1045.661462        31.298997  74.634525
#
#     avg_wind_speed  cloud_cover
# 0         7.845981    20.851051
# 1         5.382457    93.059521
# 2        13.158008    11.636640
# 3         5.886677    81.744971
# 4        12.248992    38.062329
# 5         6.587024    87.797432
# 6         5.654166    86.805669
# 7         6.940197    80.592540
# 8         4.520668    79.003044
# 9        11.214141    30.467914
# 10       22.803513     8.091928
# 11        3.483190    40.298018
# 12        7.556636    49.834827
# 13        5.758368    69.495109
# 14        8.153293    34.609973
# 15        7.556636    49.834827
# 16        7.556636    49.834827
# 17        1.753471    82.248056
# 18       14.097482    13.252467
# 19        9.415621    86.201448

# %% [markdown]
# # Traditional Models

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import xgboost as xgb

# Load the dataset (assuming df is already loaded)
df = df.drop(columns=['date', 'humidity'])  # Drop date and humidity columns

# Define features and target
X = df.drop(columns=['rain_or_not'])
y = df['rain_or_not']

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE to balance the classes
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

# Define a function to perform cross-validation and evaluate models
def evaluate_model_with_cv(model, X, y, n_splits=5):
    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracy_scores = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
    roc_auc_scores = cross_val_score(model, X, y, cv=cv, scoring='roc_auc')

    print(f"Model: {model.__class__.__name__}")
    print(f"Cross-Validation Accuracy: {np.mean(accuracy_scores):.4f} (+/- {np.std(accuracy_scores):.4f})")
    print(f"Cross-Validation ROC AUC: {np.mean(roc_auc_scores):.4f} (+/- {np.std(roc_auc_scores):.4f})")

    # Fit the model on the entire dataset to get the classification report
    model.fit(X, y)
    y_pred = model.predict(X)
    print("Classification Report:\n", classification_report(y, y_pred))
    print("-" * 50)

    return np.mean(roc_auc_scores)  # Return ROC AUC score for model comparison

# Evaluate models and store their performance
models = {
    'LogisticRegression': LogisticRegression(),
    'DecisionTree': DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(n_estimators=100),
    'SVM': SVC(probability=True),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
}

best_model_name = None
best_score = -1
for name, model in models.items():
    print(f"Evaluating {name}")
    score = evaluate_model_with_cv(model, X_resampled, y_resampled)
    if score > best_score:
        best_score = score
        best_model_name = name

print(f"\nBest Model: {best_model_name} with ROC AUC: {best_score:.4f}")

# Plot feature importance for the best model
if best_model_name in ['RandomForest', 'XGBoost', 'DecisionTree']:
    best_model = models[best_model_name]
    best_model.fit(X_resampled, y_resampled)

    if best_model_name == 'RandomForest':
        importances = best_model.feature_importances_
    elif best_model_name == 'XGBoost':
        importances = best_model.feature_importances_
    elif best_model_name == 'DecisionTree':
        importances = best_model.feature_importances_

    feature_names = X.columns
    indices = np.argsort(importances)[::-1]

    plt.figure(figsize=(10, 6))
    plt.title(f"Feature Importances for {best_model_name}")
    plt.bar(range(X.shape[1]), importances[indices], align="center")
    plt.xticks(range(X.shape[1]), [feature_names[i] for i in indices], rotation=90)
    plt.xlabel("Feature")
    plt.ylabel("Importance")
    plt.tight_layout()
    plt.show()
else:
    print(f"Feature importance is not applicable for {best_model_name}")
# Out:
# Evaluating LogisticRegression
# Model: LogisticRegression
# Cross-Validation Accuracy: 0.6238 (+/- 0.0248)
# Cross-Validation ROC AUC: 0.6808 (+/- 0.0382)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.61      0.62       198
#            1       0.62      0.64      0.63       198
#
#     accuracy                           0.62       396
#    macro avg       0.62      0.62      0.62       396
# weighted avg       0.62      0.62      0.62       396
#
# --------------------------------------------------
# Evaluating DecisionTree
# Model: DecisionTreeClassifier
# Cross-Validation Accuracy: 0.6489 (+/- 0.0326)
# Cross-Validation ROC AUC: 0.6468 (+/- 0.0222)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       198
#            1       1.00      1.00      1.00       198
#
#     accuracy                           1.00       396
#    macro avg       1.00      1.00      1.00       396
# weighted avg       1.00      1.00      1.00       396
#
# --------------------------------------------------
# Evaluating RandomForest
# Model: RandomForestClassifier
# Cross-Validation Accuracy: 0.6794 (+/- 0.0208)
# Cross-Validation ROC AUC: 0.7606 (+/- 0.0387)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       198
#            1       1.00      1.00      1.00       198
#
#     accuracy                           1.00       396
#    macro avg       1.00      1.00      1.00       396
# weighted avg       1.00      1.00      1.00       396
#
# --------------------------------------------------
# Evaluating SVM
# Model: SVC
# Cross-Validation Accuracy: 0.6186 (+/- 0.0225)
# Cross-Validation ROC AUC: 0.6840 (+/- 0.0357)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.64      0.65       198
#            1       0.66      0.69      0.67       198
#
#     accuracy                           0.66       396
#    macro avg       0.66      0.66      0.66       396
# weighted avg       0.66      0.66      0.66       396
#
# --------------------------------------------------
# Evaluating XGBoost
# Model: XGBClassifier
# Cross-Validation Accuracy: 0.6617 (+/- 0.0391)
# Cross-Validation ROC AUC: 0.7149 (+/- 0.0405)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       198
#            1       1.00      0.99      1.00       198
#
#     accuracy                           1.00       396
#    macro avg       1.00      1.00      1.00       396
# weighted avg       1.00      1.00      1.00       396
#
# --------------------------------------------------
#
# Best Model: RandomForest with ROC AUC: 0.7606

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt
import lightgbm as lgb
import warnings
import logging

# Configure logging to ignore LightGBM warnings
logging.getLogger('lightgbm').setLevel(logging.ERROR)

# Load the dataset (assuming df is already loaded)
df = pd.read_csv('/content/weather_data_preprocessed.csv')  # Uncomment and modify this line to load your dataset

# Drop date and humidity columns
df = df.drop(columns=['date', 'humidity'])

# Define features and target
X = df.drop(columns=['rain_or_not'])
y = df['rain_or_not']

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE to balance the classes
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

# Define a function to perform cross-validation and evaluate models
def evaluate_model_with_cv(model, X, y, n_splits=5):
    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracy_scores = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
    roc_auc_scores = cross_val_score(model, X, y, cv=cv, scoring='roc_auc')

    accuracy_mean = np.mean(accuracy_scores)
    roc_auc_mean = np.mean(roc_auc_scores)

    print(f"Model: {model.__class__.__name__}")
    print(f"Cross-Validation Accuracy: {accuracy_mean:.4f} (+/- {np.std(accuracy_scores):.4f})")
    print(f"Cross-Validation ROC AUC: {roc_auc_mean:.4f} (+/- {np.std(roc_auc_scores):.4f})")

    # Fit the model on the entire dataset to get the classification report
    model.fit(X, y)
    y_pred = model.predict(X)
    print("Classification Report:\n", classification_report(y, y_pred))
    print("-" * 50)

    return accuracy_mean, roc_auc_mean  # Return both accuracy and ROC AUC scores for model comparison

# Evaluate LightGBM model
print("Evaluating LightGBM")
lgbm_model = lgb.LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
accuracy_score, roc_auc_score = evaluate_model_with_cv(lgbm_model, X_resampled, y_resampled)

print(f"LightGBM Cross-Validation Accuracy: {accuracy_score:.4f}")
print(f"LightGBM ROC AUC: {roc_auc_score:.4f}")

# Plot feature importance for LightGBM
importance = lgbm_model.feature_importances_
feature_names = X.columns
indices = np.argsort(importance)[::-1]

plt.figure(figsize=(10, 6))
plt.title("Feature Importances for LightGBM")
plt.bar(range(X.shape[1]), importance[indices], align="center")
plt.xticks(range(X.shape[1]), [feature_names[i] for i in indices], rotation=90)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.tight_layout()
plt.show()
# Out:
# Evaluating LightGBM
# Model: LGBMClassifier
# Cross-Validation Accuracy: 0.6894 (+/- 0.0234)
# Cross-Validation ROC AUC: 0.7252 (+/- 0.0372)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99       198
#            1       0.98      1.00      0.99       198
#
#     accuracy                           0.99       396
#    macro avg       0.99      0.99      0.99       396
# weighted avg       0.99      0.99      0.99       396
#
# --------------------------------------------------
# LightGBM Cross-Validation Accuracy: 0.6894
# LightGBM ROC AUC: 0.7252

# %%
def evaluate_model_with_cv(model, X, y, n_splits=5):
    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracy_scores = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
    roc_auc_scores = cross_val_score(model, X, y, cv=cv, scoring='roc_auc')

    print(f"Model: {model.__class__.__name__}")
    print(f"Cross-Validation Accuracy: {np.mean(accuracy_scores):.4f} (+/- {np.std(accuracy_scores):.4f})")
    print(f"Cross-Validation ROC AUC: {np.mean(roc_auc_scores):.4f} (+/- {np.std(roc_auc_scores):.4f})")

    # Fit the model on the entire dataset to get the classification report
    model.fit(X, y)
    y_pred = model.predict(X)
    print("Classification Report:\n", classification_report(y, y_pred))
    print("-" * 50)

    return np.mean(roc_auc_scores)  # Return ROC AUC score for model comparison

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import cross_val_predict

# Load the dataset (assuming df is already loaded)
df = pd.read_csv('/content/weather_data_preprocessed.csv')  # Uncomment and modify this line to load your dataset

# Drop date and humidity columns
df = df.drop(columns=['date', 'humidity'])

# Define features and target
X = df.drop(columns=['rain_or_not'])
y = df['rain_or_not']

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE to balance the classes
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

# Define base models
rf = RandomForestClassifier(n_estimators=100, random_state=42)
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
dt = DecisionTreeClassifier(random_state=42)
lgbm_model = lgb.LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42,verbosity=-1)

# Create an ensemble model using soft voting
ensemble_model = VotingClassifier(
    estimators=[
        ('RandomForest', rf),
        #('XGBoost', xgb_model),
        #('DecisionTree', dt),
        ('LightBGM', lgbm_model)
    ],
    voting='soft'
)

# Evaluate the ensemble model
print("Evaluating Ensemble Model")
evaluate_model_with_cv(ensemble_model, X_resampled, y_resampled)
# Out:
# Evaluating Ensemble Model
# Model: VotingClassifier
# Cross-Validation Accuracy: 0.6944 (+/- 0.0271)
# Cross-Validation ROC AUC: 0.7418 (+/- 0.0327)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       198
#            1       0.99      1.00      1.00       198
#
#     accuracy                           1.00       396
#    macro avg       1.00      1.00      1.00       396
# weighted avg       1.00      1.00      1.00       396
#
# --------------------------------------------------
# 0.741801282051282

# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from imblearn.combine import SMOTEENN

# Suppress warnings
warnings.filterwarnings("ignore")

# Load dataset
df = pd.read_csv('/content/weather_data_preprocessed.csv')

# Drop unnecessary columns
df = df.drop(columns=['date', 'humidity'])

# Define features and target
X = df.drop(columns=['rain_or_not'])
y = df['rain_or_not']

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE-ENN
smote_enn = SMOTEENN(random_state=42)
X_resampled, y_resampled = smote_enn.fit_resample(X_scaled, y)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# Define base models
rf = RandomForestClassifier(n_estimators=100, random_state=42)
xgb_model = xgb.XGBClassifier(eval_metric='logloss', random_state=42)
dt = DecisionTreeClassifier(random_state=42)
lgbm_model = lgb.LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42, verbosity=-1)

# Create an ensemble model using soft voting
ensemble_model = VotingClassifier(
    estimators=[
        ('RandomForest', rf),
        ('XGBoost', xgb_model),
        ('DecisionTree', dt),
        ('LightGBM', lgbm_model)
    ],
    voting='soft'
)

# Train the model
ensemble_model.fit(X_train, y_train)

# Predictions
y_pred = ensemble_model.predict(X_test)
y_prob = ensemble_model.predict_proba(X_test)[:, 1]

# Evaluation Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)

# Print results
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'ROC-AUC Score: {roc_auc:.4f}')
# Out:
# Accuracy: 0.8846
# Precision: 0.9091
# Recall: 0.8333
# F1 Score: 0.8696
# ROC-AUC Score: 0.9167

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix


df = pd.read_csv("/content/weather_data_preprocessed.csv")

# 🔹 Convert Date to Datetime
df["date"] = pd.to_datetime(df["date"])  # Convert date to datetime format
df["day_of_year"] = df["date"].dt.dayofyear  # Extract day of year
df["month"] = df["date"].dt.month  # Extract month
df["season"] = df["month"] % 12 // 3 + 1  # Create season feature

X = df.drop(["date", "rain_or_not"], axis=1)  # Drop date & target
y = df["rain_or_not"]  # Target variable

# 🔹 Normalize Features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# 🔹 Convert to Sequences (for LSTM)
def create_sequences(data, labels, sequence_length=10):
    Xs, ys = [], []
    for i in range(len(data) - sequence_length):
        Xs.append(data[i : i + sequence_length])
        ys.append(labels[i + sequence_length])
    return np.array(Xs), np.array(ys)

sequence_length = 15
X_seq, y_seq = create_sequences(X_scaled, y.values, sequence_length)

# 🔹 Split Data
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# 🔹 Handle Class Imbalance with SMOTE
X_train_resampled, y_train_resampled = SMOTE(random_state=42).fit_resample(
    X_train.reshape(X_train.shape[0], -1), y_train
)
X_train_resampled = X_train_resampled.reshape(-1, sequence_length, X_train.shape[2])  # Reshape for LSTM

# 🔹 Define LSTM Model
model = Sequential([
    Bidirectional(LSTM(128, return_sequences=True, input_shape=(sequence_length, X_train.shape[2]))),
    Dropout(0.3),
    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.3),
    LSTM(32),
    Dropout(0.3),
    Dense(1, activation="sigmoid")  # Binary Classification Output
])

# 🔹 Compile Model
model.compile(optimizer=Adam(learning_rate=0.001), loss="binary_crossentropy", metrics=["accuracy"])

# 🔹 Train Model
history = model.fit(X_train_resampled, y_train_resampled, validation_data=(X_test, y_test),
                    epochs=100, batch_size=16, verbose=1)

# 🔹 Evaluate Model
y_pred = (model.predict(X_test) > 0.5).astype(int)
print(classification_report(y_test, y_pred))

# 🔹 Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 13s 168ms/step - accuracy: 0.6286 - loss: 0.6838 - val_accuracy: 0.7500 - val_loss: 0.6438
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.6809 - loss: 0.6321 - val_accuracy: 0.6167 - val_loss: 0.6261
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5854 - loss: 0.6998 - val_accuracy: 0.6500 - val_loss: 0.6512
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6307 - loss: 0.6510 - val_accuracy: 0.6667 - val_loss: 0.6224
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6618 - loss: 0.6317 - val_accuracy: 0.6833 - val_loss: 0.6284
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.6909 - loss: 0.6318 - val_accuracy: 0.7167 - val_loss: 0.6158
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6636 - loss: 0.6473 - val_accuracy: 0.6833 - val_loss: 0.6346
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.6997 - loss: 0.6291 - val_accuracy: 0.6667 - val_loss: 0.6221
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.6565 - loss: 0.6366 - val_accuracy: 0.6833 - val_loss: 0.6299
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.6409 - loss: 0.6332 - val_accuracy: 0.7000 - val_loss: 0.6053
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8012 - loss: 0.4619 - val_accuracy: 0.5333 - val_loss: 0.9305
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.7758 - loss: 0.4784 - val_accuracy: 0.5333 - val_loss: 0.7622
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.7734 - loss: 0.4934 - val_accuracy: 0.4667 - val_loss: 0.8462
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.7882 - loss: 0.4713 - val_accuracy: 0.5333 - val_loss: 0.8927
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.7964 - loss: 0.4292 - val_accuracy: 0.5500 - val_loss: 0.9514
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.7361 - loss: 0.5138 - val_accuracy: 0.5500 - val_loss: 0.8147
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.8037 - loss: 0.4588 - val_accuracy: 0.5667 - val_loss: 0.8966
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7780 - loss: 0.4695 - val_accuracy: 0.5333 - val_loss: 0.8792
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8237 - loss: 0.4439 - val_accuracy: 0.5500 - val_loss: 0.9012
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.8210 - loss: 0.4041 - val_accuracy: 0.5167 - val_loss: 0.8053
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.7338 - loss: 0.5022 - val_accuracy: 0.5333 - val_loss: 0.8604
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7231 - loss: 0.5248 - val_accuracy: 0.5333 - val_loss: 0.8254
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.7639 - loss: 0.4941 - val_accuracy: 0.5833 - val_loss: 0.8523
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 871ms/step
#               precision    recall  f1-score   support
#
#            0       0.52      0.62      0.56        26
#            1       0.66      0.56      0.60        34
#
#     accuracy                           0.58        60
#    macro avg       0.59      0.59      0.58        60
# weighted avg       0.59      0.58      0.59        60

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# 🔹 Load Dataset
df = pd.read_csv("/content/weather_data_preprocessed.csv")  # Update with the actual file path

# 🔹 Convert Date & Extract Features
df["date"] = pd.to_datetime(df["date"])
df["day_of_year"] = df["date"].dt.dayofyear
df["month"] = df["date"].dt.month
df["season"] = df["month"] % 12 // 3 + 1  # 1: Winter, 2: Spring, 3: Summer, 4: Fall

# 🔹 Select Features & Target
features = ["pressure", "avg_temperature", "avg_wind_speed", "cloud_cover", "day_of_year", "season"]
X = df[features]
y = df["rain_or_not"]

# 🔹 Normalize Data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# 🔹 Convert to Sequences
def create_sequences(data, labels, sequence_length=10):
    Xs, ys = [], []
    for i in range(len(data) - sequence_length):
        Xs.append(data[i : i + sequence_length])
        ys.append(labels[i + sequence_length])
    return np.array(Xs), np.array(ys)

sequence_length = 10
X_seq, y_seq = create_sequences(X_scaled, y.values, sequence_length)

# 🔹 Split Data
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42, stratify=y_seq)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42, stratify=y_train)

# 🔹 Compute Class Weights
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_train), y=y_train)
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

# 🔹 Build RNN Model
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(sequence_length, X_train.shape[2])),
    Dropout(0.3),

    LSTM(64, return_sequences=True),
    Dropout(0.3),

    LSTM(32),
    Dropout(0.3),

    Dense(1, activation="sigmoid")  # Binary classification
])

# 🔹 Compile Model
model.compile(optimizer=Adam(learning_rate=0.001), loss="binary_crossentropy", metrics=["accuracy"])

# 🔹 Learning Rate Scheduler
lr_scheduler = ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.5, min_lr=1e-5)

# 🔹 Train Model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val),
                    epochs=100, batch_size=32, verbose=1, class_weight=class_weight_dict,
                    callbacks=[lr_scheduler])

# 🔹 Convert History to DataFrame
his = pd.DataFrame(history.history)

# 🔹 Plot Loss
plt.figure(figsize=(10,5))
sns.lineplot(data=his[["loss", "val_loss"]])
plt.title("Loss & Validation Loss")
plt.show()
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 241ms/step - accuracy: 0.5848 - loss: 0.6841 - val_accuracy: 0.6667 - val_loss: 0.6590 - learning_rate: 0.0010
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6311 - loss: 0.6700 - val_accuracy: 0.6250 - val_loss: 0.6652 - learning_rate: 0.0010
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5636 - loss: 0.6693 - val_accuracy: 0.7917 - val_loss: 0.6278 - learning_rate: 0.0010
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6619 - loss: 0.6619 - val_accuracy: 0.7917 - val_loss: 0.5936 - learning_rate: 0.0010
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6234 - loss: 0.6717 - val_accuracy: 0.7083 - val_loss: 0.5887 - learning_rate: 0.0010
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6375 - loss: 0.6626 - val_accuracy: 0.7917 - val_loss: 0.5722 - learning_rate: 0.0010
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6380 - loss: 0.6474 - val_accuracy: 0.6667 - val_loss: 0.6178 - learning_rate: 0.0010
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5677 - loss: 0.6576 - val_accuracy: 0.7083 - val_loss: 0.5954 - learning_rate: 0.0010
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6570 - loss: 0.6403 - val_accuracy: 0.7500 - val_loss: 0.5709 - learning_rate: 0.0010
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6633 - loss: 0.6650 - val_accuracy: 0.7083 - val_loss: 0.5942 - learning_rate: 0.0010
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6395 - loss: 0.6475 - val_accuracy: 0.6667 - val_loss: 0.5992 - learning_rate: 0.0010
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6442 - loss: 0.6345 - val_accuracy: 0.7500 - val_loss: 0.5739 - learning_rate: 0.0010
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6956 - loss: 0.6258 - val_accuracy: 0.7083 - val_loss: 0.5924 - learning_rate: 0.0010
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6526 - loss: 0.6557 - val_accuracy: 0.6667 - val_loss: 0.5981 - learning_rate: 0.0010
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6510 - loss: 0.6504 - val_accuracy: 0.7083 - val_loss: 0.5845 - learning_rate: 5.0000e-04
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6738 - loss: 0.6488 - val_accuracy: 0.7083 - val_loss: 0.5836 - learning_rate: 5.0000e-04
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.6635 - loss: 0.6504 - val_accuracy: 0.7083 - val_loss: 0.5828 - learning_rate: 5.0000e-04
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.6239 - loss: 0.6517 - val_accuracy: 0.7083 - val_loss: 0.5834 - learning_rate: 5.0000e-04
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.6545 - loss: 0.6415 - val_accuracy: 0.6667 - val_loss: 0.5859 - learning_rate: 5.0000e-04
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6044 - loss: 0.6576 - val_accuracy: 0.7083 - val_loss: 0.5825 - learning_rate: 2.5000e-04
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6375 - loss: 0.6659 - val_accuracy: 0.7083 - val_loss: 0.5791 - learning_rate: 2.5000e-04
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6861 - loss: 0.6341 - val_accuracy: 0.7083 - val_loss: 0.5783 - learning_rate: 2.5000e-04
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6376 - loss: 0.6454 - val_accuracy: 0.7083 - val_loss: 0.5794 - learning_rate: 2.5000e-04
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6663 - loss: 0.6490 - val_accuracy: 0.6667 - val_loss: 0.5825 - learning_rate: 2.5000e-04
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6779 - loss: 0.6273 - val_accuracy: 0.6667 - val_loss: 0.5815 - learning_rate: 1.2500e-04
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6521 - loss: 0.6486 - val_accuracy: 0.6667 - val_loss: 0.5810 - learning_rate: 1.2500e-04
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6762 - loss: 0.6145 - val_accuracy: 0.6667 - val_loss: 0.5796 - learning_rate: 1.2500e-04
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6645 - loss: 0.6197 - val_accuracy: 0.6667 - val_loss: 0.5791 - learning_rate: 1.2500e-04
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6624 - loss: 0.6536 - val_accuracy: 0.6667 - val_loss: 0.5833 - learning_rate: 1.2500e-04
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6834 - loss: 0.6154 - val_accuracy: 0.6667 - val_loss: 0.5828 - learning_rate: 6.2500e-05
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6478 - loss: 0.6289 - val_accuracy: 0.6667 - val_loss: 0.5800 - learning_rate: 1.0000e-05
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6822 - loss: 0.6413 - val_accuracy: 0.6667 - val_loss: 0.5801 - learning_rate: 1.0000e-05
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6024 - loss: 0.6604 - val_accuracy: 0.6667 - val_loss: 0.5800 - learning_rate: 1.0000e-05
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6482 - loss: 0.6289 - val_accuracy: 0.6667 - val_loss: 0.5800 - learning_rate: 1.0000e-05
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6582 - loss: 0.6365 - val_accuracy: 0.6667 - val_loss: 0.5802 - learning_rate: 1.0000e-05
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6484 - loss: 0.6625 - val_accuracy: 0.6667 - val_loss: 0.5805 - learning_rate: 1.0000e-05
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6391 - loss: 0.6516 - val_accuracy: 0.6667 - val_loss: 0.5806 - learning_rate: 1.0000e-05
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6598 - loss: 0.6539 - val_accuracy: 0.6667 - val_loss: 0.5807 - learning_rate: 1.0000e-05
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6839 - loss: 0.6091 - val_accuracy: 0.6667 - val_loss: 0.5804 - learning_rate: 1.0000e-05
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6240 - loss: 0.6705 - val_accuracy: 0.6667 - val_loss: 0.5805 - learning_rate: 1.0000e-05
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6631 - loss: 0.6353 - val_accuracy: 0.6667 - val_loss: 0.5805 - learning_rate: 1.0000e-05
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6441 - loss: 0.6441 - val_accuracy: 0.6667 - val_loss: 0.5805 - learning_rate: 1.0000e-05
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6174 - loss: 0.6315 - val_accuracy: 0.6667 - val_loss: 0.5805 - learning_rate: 1.0000e-05
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6476 - loss: 0.6583 - val_accuracy: 0.6667 - val_loss: 0.5806 - learning_rate: 1.0000e-05
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6339 - loss: 0.6333 - val_accuracy: 0.6667 - val_loss: 0.5806 - learning_rate: 1.0000e-05
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6346 - loss: 0.6529 - val_accuracy: 0.6667 - val_loss: 0.5806 - learning_rate: 1.0000e-05
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6863 - loss: 0.6145 - val_accuracy: 0.6667 - val_loss: 0.5805 - learning_rate: 1.0000e-05
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6700 - loss: 0.6397 - val_accuracy: 0.6667 - val_loss: 0.5806 - learning_rate: 1.0000e-05
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.6393 - loss: 0.6530 - val_accuracy: 0.6667 - val_loss: 0.5807 - learning_rate: 1.0000e-05
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6311 - loss: 0.6435 - val_accuracy: 0.6667 - val_loss: 0.5806 - learning_rate: 1.0000e-05
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.6437 - loss: 0.6322 - val_accuracy: 0.6667 - val_loss: 0.5806 - learning_rate: 1.0000e-05
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.6204 - loss: 0.6668 - val_accuracy: 0.6667 - val_loss: 0.5807 - learning_rate: 1.0000e-05
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.6669 - loss: 0.6198 - val_accuracy: 0.6667 - val_loss: 0.5805 - learning_rate: 1.0000e-05
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6383 - loss: 0.6468 - val_accuracy: 0.6667 - val_loss: 0.5808 - learning_rate: 1.0000e-05
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6451 - loss: 0.6518 - val_accuracy: 0.6667 - val_loss: 0.5809 - learning_rate: 1.0000e-05
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6070 - loss: 0.6755 - val_accuracy: 0.6667 - val_loss: 0.5810 - learning_rate: 1.0000e-05
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7105 - loss: 0.6306 - val_accuracy: 0.6667 - val_loss: 0.5806 - learning_rate: 1.0000e-05
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6679 - loss: 0.6313 - val_accuracy: 0.6667 - val_loss: 0.5807 - learning_rate: 1.0000e-05
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6153 - loss: 0.6535 - val_accuracy: 0.6667 - val_loss: 0.5806 - learning_rate: 1.0000e-05
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6329 - loss: 0.6740 - val_accuracy: 0.6667 - val_loss: 0.5806 - learning_rate: 1.0000e-05
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6263 - loss: 0.6424 - val_accuracy: 0.6667 - val_loss: 0.5803 - learning_rate: 1.0000e-05
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6329 - loss: 0.6454 - val_accuracy: 0.6667 - val_loss: 0.5802 - learning_rate: 1.0000e-05
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6305 - loss: 0.6392 - val_accuracy: 0.6667 - val_loss: 0.5803 - learning_rate: 1.0000e-05
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6263 - loss: 0.6561 - val_accuracy: 0.6667 - val_loss: 0.5802 - learning_rate: 1.0000e-05
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6881 - loss: 0.6073 - val_accuracy: 0.6667 - val_loss: 0.5803 - learning_rate: 1.0000e-05
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6348 - loss: 0.6449 - val_accuracy: 0.6667 - val_loss: 0.5805 - learning_rate: 1.0000e-05
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6471 - loss: 0.6153 - val_accuracy: 0.6667 - val_loss: 0.5803 - learning_rate: 1.0000e-05
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6250 - loss: 0.6426 - val_accuracy: 0.6667 - val_loss: 0.5804 - learning_rate: 1.0000e-05

# %%
from sklearn.metrics import classification_report, confusion_matrix

# 🔹 Evaluate Model on Test Data
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")

# 🔹 Make Predictions
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)  # Convert probabilities to binary labels

# 🔹 Print Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# 🔹 Compute Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# 🔹 Plot Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["No Rain", "Rain"], yticklabels=["No Rain", "Rain"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Test Loss: 0.6621
# Test Accuracy: 0.6230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 492ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.61      0.55        23
#            1       0.73      0.63      0.68        38
#
#     accuracy                           0.62        61
#    macro avg       0.61      0.62      0.61        61
# weighted avg       0.64      0.62      0.63        61

# %% [markdown]
# # Hyperparameter Optimization

# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from imblearn.combine import SMOTEENN

# Suppress warnings
warnings.filterwarnings("ignore")

# Load dataset
df = pd.read_csv('/content/weather_data_preprocessed.csv')

# Drop unnecessary columns
df = df.drop(columns=['date', 'humidity'])

# Define features and target
X = df.drop(columns=['rain_or_not'])
y = df['rain_or_not']

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE-ENN
smote_enn = SMOTEENN(random_state=42)
X_resampled, y_resampled = smote_enn.fit_resample(X_scaled, y)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# Define base models
rf = RandomForestClassifier(random_state=42)
xgb_model = xgb.XGBClassifier(eval_metric='logloss', random_state=42)
dt = DecisionTreeClassifier(random_state=42)
lgbm_model = lgb.LGBMClassifier(random_state=42, verbosity=-1)

# Define hyperparameter grid for optimization
param_grid = {
    'RandomForest__n_estimators': [100, 200],
    'RandomForest__max_depth': [10, 20],
   # 'XGBoost__n_estimators': [100, 200],
   # 'XGBoost__learning_rate': [0.01, 0.1],
    'LightGBM__n_estimators': [100, 200],
    'LightGBM__learning_rate': [0.01, 0.1]
}

# Create an ensemble model using soft voting
ensemble_model = VotingClassifier(
    estimators=[
        ('RandomForest', rf),
       # ('XGBoost', xgb_model),
        #('DecisionTree', dt),
        ('LightGBM', lgbm_model)
    ],
    voting='soft'
)

# Hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(ensemble_model, param_grid, cv=3, scoring='accuracy', n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# Best model from GridSearchCV
best_model = grid_search.best_estimator_

# Predictions
y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:, 1]

# Evaluation Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)

# Print best parameters & evaluation results
print("Best Parameters:", grid_search.best_params_)
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'ROC-AUC Score: {roc_auc:.4f}')
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best Parameters: {'LightGBM__learning_rate': 0.01, 'LightGBM__n_estimators': 200, 'RandomForest__max_depth': 10, 'RandomForest__n_estimators': 100}
# Accuracy: 0.8846
# Precision: 0.9091
# Recall: 0.8333
# F1 Score: 0.8696
# ROC-AUC Score: 0.9345

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import cross_val_predict

# Define base models
rf = RandomForestClassifier(n_estimators=100, random_state=42)
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
dt = DecisionTreeClassifier(random_state=42)
lgbm_model = lgb.LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42, verbosity=-1)

# Create an ensemble model using soft voting
ensemble_model = VotingClassifier(
    estimators=[
        ('RandomForest', rf),
        #('XGBoost', xgb_model),
        #('DecisionTree', dt),
        ('LightBGM', lgbm_model)
    ],
    voting='soft'
)

# Fit the ensemble model
ensemble_model.fit(X_resampled, y_resampled)

# Predict probabilities
probabilities = ensemble_model.predict_proba(X_resampled)

# Evaluate the ensemble model
print("Evaluating Ensemble Model")
evaluate_model_with_cv(ensemble_model, X_resampled, y_resampled)

# Example of how to access probabilities for the first sample
print("Probabilities for the first sample:", probabilities[0])
# Out:
# Evaluating Ensemble Model
# Model: VotingClassifier
# Cross-Validation Accuracy: 0.8575 (+/- 0.0731)
# Cross-Validation ROC AUC: 0.9379 (+/- 0.0420)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        66
#            1       1.00      1.00      1.00        60
#
#     accuracy                           1.00       126
#    macro avg       1.00      1.00      1.00       126
# weighted avg       1.00      1.00      1.00       126
#
# --------------------------------------------------
# Probabilities for the first sample: [0.70865536 0.29134464]
