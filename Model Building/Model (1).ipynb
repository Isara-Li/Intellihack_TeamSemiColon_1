# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/weather_data_preprocessed.csv")

# %%
df.head(20)
# Out:
#           date  rain_or_not     pressure  avg_temperature   humidity  \
# 0   2023-01-01            1   992.965681        23.745401  46.140905
# 1   2023-01-02            1  1037.273025        30.030503  59.876587
# 2   2023-01-03            1  1034.193357        28.365224  51.464618
# 3   2023-01-04            1   968.610142        27.550929  53.103799
# 4   2023-01-05            1  1030.264331        23.639303  57.826186
# 5   2023-01-06            1   995.818689        24.148136  49.703435
# 6   2023-01-07            1   998.296887        23.671006  63.997418
# 7   2023-01-08            1   963.347997        32.245441  67.083073
# 8   2023-01-09            1   958.060151        30.078517  64.088581
# 9   2023-01-10            1  1022.793931        31.620631  71.876470
# 10  2023-01-11            1   999.646115        25.205845  58.365841
# 11  2023-01-12            1   993.685070        35.000000  75.557750
# 12  2023-01-13            0  1022.950823        25.983840  55.041385
# 13  2023-01-14            1  1026.551290        28.416595  62.480013
# 14  2023-01-15            1   965.890817        28.509556  68.886958
# 15  2023-01-16            1  1011.022515        25.983840  55.041385
# 16  2023-01-17            0   963.535408        25.983840  55.041385
# 17  2023-01-18            1  1025.137509        33.019024  68.651421
# 18  2023-01-19            1  1015.695516        32.409620  67.795797
# 19  2023-01-20            1  1045.661462        31.298997  74.634525
#
#     avg_wind_speed  cloud_cover
# 0         7.845981    20.851051
# 1         5.382457    93.059521
# 2        13.158008    11.636640
# 3         5.886677    81.744971
# 4        12.248992    38.062329
# 5         6.587024    87.797432
# 6         5.654166    86.805669
# 7         6.940197    80.592540
# 8         4.520668    79.003044
# 9        11.214141    30.467914
# 10       22.803513     8.091928
# 11        3.483190    40.298018
# 12        7.556636    49.834827
# 13        5.758368    69.495109
# 14        8.153293    34.609973
# 15        7.556636    49.834827
# 16        7.556636    49.834827
# 17        1.753471    82.248056
# 18       14.097482    13.252467
# 19        9.415621    86.201448

# %% [markdown]
# # Building Models

# %% [markdown]
# - The features are standardized using StandardScaler.
# - SMOTE (Synthetic Minority Over-sampling Technique) is applied to balance the classes in the dataset.
# - Five classification models are initialized: Logistic Regression, Decision Tree, Random Forest, SVM, and XGBoost.
# - Each model is evaluated using the defined function, and the results are printed, including the classification report for the model fit on the entire dataset.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import xgboost as xgb

df = df.drop(columns=['date', 'humidity']) 

X = df.drop(columns=['rain_or_not'])
y = df['rain_or_not']

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE to balance the classes
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

def evaluate_model_with_cv(model, X, y, n_splits=5):
    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracy_scores = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
    roc_auc_scores = cross_val_score(model, X, y, cv=cv, scoring='roc_auc')

    print(f"Model: {model.__class__.__name__}")
    print(f"Cross-Validation Accuracy: {np.mean(accuracy_scores):.4f} (+/- {np.std(accuracy_scores):.4f})")
    print(f"Cross-Validation ROC AUC: {np.mean(roc_auc_scores):.4f} (+/- {np.std(roc_auc_scores):.4f})")

    model.fit(X, y)
    y_pred = model.predict(X)
    print("Classification Report:\n", classification_report(y, y_pred))
    print("-" * 50)

    return np.mean(roc_auc_scores)  

# Evaluate models and store their performance
models = {
    'LogisticRegression': LogisticRegression(),
    'DecisionTree': DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(n_estimators=100),
    'SVM': SVC(probability=True),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
}

best_model_name = None
best_score = -1
for name, model in models.items():
    print(f"Evaluating {name}")
    score = evaluate_model_with_cv(model, X_resampled, y_resampled)
    if score > best_score:
        best_score = score
        best_model_name = name

print(f"\nBest Model: {best_model_name} with ROC AUC: {best_score:.4f}")

# Plot feature importance for the best model
if best_model_name in ['RandomForest', 'XGBoost', 'DecisionTree']:
    best_model = models[best_model_name]
    best_model.fit(X_resampled, y_resampled)

    if best_model_name == 'RandomForest':
        importances = best_model.feature_importances_
    elif best_model_name == 'XGBoost':
        importances = best_model.feature_importances_
    elif best_model_name == 'DecisionTree':
        importances = best_model.feature_importances_

    feature_names = X.columns
    indices = np.argsort(importances)[::-1]

    plt.figure(figsize=(10, 6))
    plt.title(f"Feature Importances for {best_model_name}")
    plt.bar(range(X.shape[1]), importances[indices], align="center")
    plt.xticks(range(X.shape[1]), [feature_names[i] for i in indices], rotation=90)
    plt.xlabel("Feature")
    plt.ylabel("Importance")
    plt.tight_layout()
    plt.show()
else:
    print(f"Feature importance is not applicable for {best_model_name}")
# Out:
# Evaluating LogisticRegression
# Model: LogisticRegression
# Cross-Validation Accuracy: 0.6238 (+/- 0.0248)
# Cross-Validation ROC AUC: 0.6808 (+/- 0.0382)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.61      0.62       198
#            1       0.62      0.64      0.63       198
#
#     accuracy                           0.62       396
#    macro avg       0.62      0.62      0.62       396
# weighted avg       0.62      0.62      0.62       396
#
# --------------------------------------------------
# Evaluating DecisionTree
# Model: DecisionTreeClassifier
# Cross-Validation Accuracy: 0.6363 (+/- 0.0411)
# Cross-Validation ROC AUC: 0.6317 (+/- 0.0267)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       198
#            1       1.00      1.00      1.00       198
#
#     accuracy                           1.00       396
#    macro avg       1.00      1.00      1.00       396
# weighted avg       1.00      1.00      1.00       396
#
# --------------------------------------------------
# Evaluating RandomForest
# Model: RandomForestClassifier
# Cross-Validation Accuracy: 0.6591 (+/- 0.0201)
# Cross-Validation ROC AUC: 0.7479 (+/- 0.0251)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       198
#            1       1.00      1.00      1.00       198
#
#     accuracy                           1.00       396
#    macro avg       1.00      1.00      1.00       396
# weighted avg       1.00      1.00      1.00       396
#
# --------------------------------------------------
# Evaluating SVM
# Model: SVC
# Cross-Validation Accuracy: 0.6186 (+/- 0.0225)
# Cross-Validation ROC AUC: 0.6840 (+/- 0.0357)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.64      0.65       198
#            1       0.66      0.69      0.67       198
#
#     accuracy                           0.66       396
#    macro avg       0.66      0.66      0.66       396
# weighted avg       0.66      0.66      0.66       396
#
# --------------------------------------------------
# Evaluating XGBoost
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:01:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Model: XGBClassifier
# Cross-Validation Accuracy: 0.6617 (+/- 0.0391)
# Cross-Validation ROC AUC: 0.7149 (+/- 0.0405)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       198
#            1       1.00      0.99      1.00       198
#
#     accuracy                           1.00       396
#    macro avg       1.00      1.00      1.00       396
# weighted avg       1.00      1.00      1.00       396
#
# --------------------------------------------------
#
# Best Model: RandomForest with ROC AUC: 0.7479

# %% [markdown]
# LightGBM Model

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt
import lightgbm as lgb
import warnings
import logging


logging.getLogger('lightgbm').setLevel(logging.ERROR)

df = pd.read_csv('/content/weather_data_preprocessed.csv')

df = df.drop(columns=['date', 'humidity'])
X = df.drop(columns=['rain_or_not'])
y = df['rain_or_not']

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE to balance the classes
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

def evaluate_model_with_cv(model, X, y, n_splits=5):
    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracy_scores = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
    roc_auc_scores = cross_val_score(model, X, y, cv=cv, scoring='roc_auc')

    accuracy_mean = np.mean(accuracy_scores)
    roc_auc_mean = np.mean(roc_auc_scores)

    print(f"Model: {model.__class__.__name__}")
    print(f"Cross-Validation Accuracy: {accuracy_mean:.4f} (+/- {np.std(accuracy_scores):.4f})")
    print(f"Cross-Validation ROC AUC: {roc_auc_mean:.4f} (+/- {np.std(roc_auc_scores):.4f})")

    # Fit the model on the entire dataset to get the classification report
    model.fit(X, y)
    y_pred = model.predict(X)
    print("Classification Report:\n", classification_report(y, y_pred))
    print("-" * 50)

    return accuracy_mean, roc_auc_mean  

# Evaluate LightGBM model
print("Evaluating LightGBM")
lgbm_model = lgb.LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
accuracy_score, roc_auc_score = evaluate_model_with_cv(lgbm_model, X_resampled, y_resampled)

print(f"LightGBM Cross-Validation Accuracy: {accuracy_score:.4f}")
print(f"LightGBM ROC AUC: {roc_auc_score:.4f}")

# Plot feature importance for LightGBM
importance = lgbm_model.feature_importances_
feature_names = X.columns
indices = np.argsort(importance)[::-1]

plt.figure(figsize=(10, 6))
plt.title("Feature Importances for LightGBM")
plt.bar(range(X.shape[1]), importance[indices], align="center")
plt.xticks(range(X.shape[1]), [feature_names[i] for i in indices], rotation=90)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.tight_layout()
plt.show()
# Out:
# Evaluating LightGBM
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Model: LGBMClassifier
# Cross-Validation Accuracy: 0.6894 (+/- 0.0234)
# Cross-Validation ROC AUC: 0.7252 (+/- 0.0372)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99       198
#            1       0.98      1.00      0.99       198
#
#     accuracy                           0.99       396
#    macro avg       0.99      0.99      0.99       396
# weighted avg       0.99      0.99      0.99       396
#
# --------------------------------------------------
# LightGBM Cross-Validation Accuracy: 0.6894
# LightGBM ROC AUC: 0.7252

# %%
def evaluate_model_with_cv(model, X, y, n_splits=5):
    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracy_scores = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
    roc_auc_scores = cross_val_score(model, X, y, cv=cv, scoring='roc_auc')

    print(f"Model: {model.__class__.__name__}")
    print(f"Cross-Validation Accuracy: {np.mean(accuracy_scores):.4f} (+/- {np.std(accuracy_scores):.4f})")
    print(f"Cross-Validation ROC AUC: {np.mean(roc_auc_scores):.4f} (+/- {np.std(roc_auc_scores):.4f})")

    # Fit the model on the entire dataset to get the classification report
    model.fit(X, y)
    y_pred = model.predict(X)
    print("Classification Report:\n", classification_report(y, y_pred))
    print("-" * 50)

    return np.mean(roc_auc_scores)

# %% [markdown]
# - An ensemble model using soft voting is created with the base models. Soft voting takes the average of the predicted probabilities from each base model to make the final prediction.
# - The ensemble model is evaluated using the evaluate_model_with_cv function, which performs cross-validation and prints the accuracy and ROC AUC scores.

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import cross_val_predict

df = pd.read_csv('/content/weather_data_preprocessed.csv') 


df = df.drop(columns=['date', 'humidity'])
X = df.drop(columns=['rain_or_not'])
y = df['rain_or_not']

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE to balance the classes
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
dt = DecisionTreeClassifier(random_state=42)
lgbm_model = lgb.LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42,verbosity=-1)

# Create an ensemble model using soft voting
ensemble_model = VotingClassifier(
    estimators=[
        ('RandomForest', rf),
        #('XGBoost', xgb_model),
        #('DecisionTree', dt),
        ('LightBGM', lgbm_model)
    ],
    voting='soft'
)

# Evaluate the ensemble model
print("Evaluating Ensemble Model")
evaluate_model_with_cv(ensemble_model, X_resampled, y_resampled)
# Out:
# (396, 4)
# (396,)
# Evaluating Ensemble Model
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Model: VotingClassifier
# Cross-Validation Accuracy: 0.6944 (+/- 0.0271)
# Cross-Validation ROC AUC: 0.7418 (+/- 0.0327)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       198
#            1       0.99      1.00      1.00       198
#
#     accuracy                           1.00       396
#    macro avg       1.00      1.00      1.00       396
# weighted avg       1.00      1.00      1.00       396
#
# --------------------------------------------------
# 0.741801282051282

# %% [markdown]
# - This model uses SMOTEENN instead of SMOTE for handling class imbalance. SMOTEENN is a more robust technique that not only synthesizes new instances like SMOTE but also removes some of the noise from the minority class, which can be beneficial for small datasets and when achieving higher accuracy is challenging.

# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from imblearn.combine import SMOTEENN

# Suppress warnings
warnings.filterwarnings("ignore")


df = pd.read_csv('/content/weather_data_preprocessed.csv')
df = df.drop(columns=['date', 'humidity'])
X = df.drop(columns=['rain_or_not'])
y = df['rain_or_not']

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE-ENN
smote_enn = SMOTEENN(random_state=42)
X_resampled, y_resampled = smote_enn.fit_resample(X_scaled, y)

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
xgb_model = xgb.XGBClassifier(eval_metric='logloss', random_state=42)
dt = DecisionTreeClassifier(random_state=42)
lgbm_model = lgb.LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42, verbosity=-1)

# Create an ensemble model using soft voting
ensemble_model = VotingClassifier(
    estimators=[
        ('RandomForest', rf),
        ('XGBoost', xgb_model),
        ('DecisionTree', dt),
        ('LightGBM', lgbm_model)
    ],
    voting='soft'
)

# Train the model
ensemble_model.fit(X_train, y_train)

# Predictions
y_pred = ensemble_model.predict(X_test)
y_prob = ensemble_model.predict_proba(X_test)[:, 1]

# Evaluation Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)

# Print results
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'ROC-AUC Score: {roc_auc:.4f}')
# Out:
# Accuracy: 0.8846
# Precision: 0.9091
# Recall: 0.8333
# F1 Score: 0.8696
# ROC-AUC Score: 0.9167

# %% [markdown]
# ### Long Short-Term Memory (LSTM)

# %% [markdown]
# The LSTM model is defined with two bidirectional LSTM layers followed by dropout layers to prevent overfitting, and a final dense layer with a sigmoid activation function for binary classification. The model is compiled with the Adam optimizer and binary cross-entropy loss, and trained for 100 epochs with a batch size of 16.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix


df = pd.read_csv("/content/weather_data_preprocessed.csv")


df["date"] = pd.to_datetime(df["date"]) 
df["day_of_year"] = df["date"].dt.dayofyear 
df["month"] = df["date"].dt.month  
df["season"] = df["month"] % 12 // 3 + 1  

X = df.drop(["date", "rain_or_not"], axis=1)  
y = df["rain_or_not"]  


scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

#Convert to Sequences (for LSTM)
def create_sequences(data, labels, sequence_length=10):
    Xs, ys = [], []
    for i in range(len(data) - sequence_length):
        Xs.append(data[i : i + sequence_length])
        ys.append(labels[i + sequence_length])
    return np.array(Xs), np.array(ys)

sequence_length = 15
X_seq, y_seq = create_sequences(X_scaled, y.values, sequence_length)


X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

X_train_resampled, y_train_resampled = SMOTE(random_state=42).fit_resample(
    X_train.reshape(X_train.shape[0], -1), y_train
)
X_train_resampled = X_train_resampled.reshape(-1, sequence_length, X_train.shape[2]) 


model = Sequential([
    Bidirectional(LSTM(128, return_sequences=True, input_shape=(sequence_length, X_train.shape[2]))),
    Dropout(0.3),
    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.3),
    LSTM(32),
    Dropout(0.3),
    Dense(1, activation="sigmoid")  
])


model.compile(optimizer=Adam(learning_rate=0.001), loss="binary_crossentropy", metrics=["accuracy"])

history = model.fit(X_train_resampled, y_train_resampled, validation_data=(X_test, y_test),
                    epochs=100, batch_size=16, verbose=1)

y_pred = (model.predict(X_test) > 0.5).astype(int)
print(classification_report(y_test, y_pred))


cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 102ms/step - accuracy: 0.5051 - loss: 0.6929 - val_accuracy: 0.6500 - val_loss: 0.6328
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6541 - loss: 0.6284 - val_accuracy: 0.6167 - val_loss: 0.6534
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6254 - loss: 0.6622 - val_accuracy: 0.6833 - val_loss: 0.6277
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6416 - loss: 0.6395 - val_accuracy: 0.6833 - val_loss: 0.6338
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.6291 - loss: 0.6415 - val_accuracy: 0.6167 - val_loss: 0.6620
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6116 - loss: 0.6544 - val_accuracy: 0.6667 - val_loss: 0.6146
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6476 - loss: 0.6947 - val_accuracy: 0.6667 - val_loss: 0.6369
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6759 - loss: 0.6236 - val_accuracy: 0.6667 - val_loss: 0.6305
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6685 - loss: 0.6349 - val_accuracy: 0.6833 - val_loss: 0.6284
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6908 - loss: 0.6155 - val_accuracy: 0.7000 - val_loss: 0.6164
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6453 - loss: 0.6149 - val_accuracy: 0.7167 - val_loss: 0.6243
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6988 - loss: 0.6306 - val_accuracy: 0.7167 - val_loss: 0.6158
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.6768 - loss: 0.6180 - val_accuracy: 0.7333 - val_loss: 0.6143
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.6492 - loss: 0.6508 - val_accuracy: 0.7167 - val_loss: 0.6093
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6358 - loss: 0.6530 - val_accuracy: 0.6833 - val_loss: 0.6077
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6857 - loss: 0.6351 - val_accuracy: 0.7000 - val_loss: 0.6214
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6730 - loss: 0.6218 - val_accuracy: 0.7000 - val_loss: 0.6338
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6539 - loss: 0.6375 - val_accuracy: 0.7000 - val_loss: 0.6149
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6925 - loss: 0.5840 - val_accuracy: 0.7000 - val_loss: 0.6387
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6819 - loss: 0.6326 - val_accuracy: 0.7167 - val_loss: 0.6135
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6807 - loss: 0.6255 - val_accuracy: 0.7000 - val_loss: 0.6099
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6749 - loss: 0.6352 - val_accuracy: 0.7167 - val_loss: 0.6126
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6849 - loss: 0.6121 - val_accuracy: 0.7000 - val_loss: 0.6313
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6540 - loss: 0.6379 - val_accuracy: 0.7000 - val_loss: 0.6242
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.6433 - loss: 0.6263 - val_accuracy: 0.6333 - val_loss: 0.6407
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6836 - loss: 0.6264 - val_accuracy: 0.6667 - val_loss: 0.6380
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6127 - loss: 0.6577 - val_accuracy: 0.6333 - val_loss: 0.6404
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6908 - loss: 0.6114 - val_accuracy: 0.7167 - val_loss: 0.6124
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6831 - loss: 0.6135 - val_accuracy: 0.7000 - val_loss: 0.6156
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.7089 - loss: 0.5995 - val_accuracy: 0.7000 - val_loss: 0.6236
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6300 - loss: 0.6503 - val_accuracy: 0.7000 - val_loss: 0.6145
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6236 - loss: 0.6469 - val_accuracy: 0.6667 - val_loss: 0.6294
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.6764 - loss: 0.5984 - val_accuracy: 0.5833 - val_loss: 0.6764
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.6608 - loss: 0.6127 - val_accuracy: 0.6667 - val_loss: 0.6306
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.7210 - loss: 0.5798 - val_accuracy: 0.6667 - val_loss: 0.6290
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6694 - loss: 0.6253 - val_accuracy: 0.6667 - val_loss: 0.6207
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6555 - loss: 0.6129 - val_accuracy: 0.5833 - val_loss: 0.7362
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6675 - loss: 0.6088 - val_accuracy: 0.7167 - val_loss: 0.6057
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6593 - loss: 0.6142 - val_accuracy: 0.6833 - val_loss: 0.6160
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6892 - loss: 0.5790 - val_accuracy: 0.6667 - val_loss: 0.6285
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6804 - loss: 0.6061 - val_accuracy: 0.6833 - val_loss: 0.6128
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6731 - loss: 0.6103 - val_accuracy: 0.6667 - val_loss: 0.6388
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.6961 - loss: 0.5706 - val_accuracy: 0.6500 - val_loss: 0.6236
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.6712 - loss: 0.6109 - val_accuracy: 0.6333 - val_loss: 0.6477
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7074 - loss: 0.5842 - val_accuracy: 0.6167 - val_loss: 0.6402
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7068 - loss: 0.5852 - val_accuracy: 0.6333 - val_loss: 0.6620
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6795 - loss: 0.6021 - val_accuracy: 0.6500 - val_loss: 0.6453
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7296 - loss: 0.5707 - val_accuracy: 0.6000 - val_loss: 0.6674
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6725 - loss: 0.6134 - val_accuracy: 0.6167 - val_loss: 0.6654
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6912 - loss: 0.6024 - val_accuracy: 0.6500 - val_loss: 0.6797
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7220 - loss: 0.5769 - val_accuracy: 0.6833 - val_loss: 0.6226
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7214 - loss: 0.5728 - val_accuracy: 0.5833 - val_loss: 0.6794
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.7016 - loss: 0.5905 - val_accuracy: 0.6000 - val_loss: 0.6502
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7110 - loss: 0.5990 - val_accuracy: 0.6333 - val_loss: 0.6900
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6942 - loss: 0.5630 - val_accuracy: 0.5667 - val_loss: 0.7337
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7198 - loss: 0.5726 - val_accuracy: 0.6000 - val_loss: 0.7220
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7125 - loss: 0.5726 - val_accuracy: 0.5500 - val_loss: 0.6803
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7350 - loss: 0.5569 - val_accuracy: 0.5667 - val_loss: 0.7041
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7212 - loss: 0.5382 - val_accuracy: 0.5667 - val_loss: 0.7225
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.7697 - loss: 0.5240 - val_accuracy: 0.5833 - val_loss: 0.6890
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7398 - loss: 0.5271 - val_accuracy: 0.5167 - val_loss: 0.8666
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6933 - loss: 0.5905 - val_accuracy: 0.5167 - val_loss: 0.8083
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.6594 - loss: 0.5932 - val_accuracy: 0.6333 - val_loss: 0.6715
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7394 - loss: 0.5387 - val_accuracy: 0.5333 - val_loss: 0.7164
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7303 - loss: 0.5251 - val_accuracy: 0.6500 - val_loss: 0.6698
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7373 - loss: 0.5361 - val_accuracy: 0.5667 - val_loss: 0.7444
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7454 - loss: 0.5472 - val_accuracy: 0.5833 - val_loss: 0.7443
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7484 - loss: 0.5212 - val_accuracy: 0.5333 - val_loss: 0.7526
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7289 - loss: 0.5555 - val_accuracy: 0.5833 - val_loss: 0.7536
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7652 - loss: 0.5236 - val_accuracy: 0.5833 - val_loss: 0.7634
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7427 - loss: 0.5108 - val_accuracy: 0.5167 - val_loss: 0.7927
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7830 - loss: 0.5046 - val_accuracy: 0.5667 - val_loss: 0.7857
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7804 - loss: 0.5262 - val_accuracy: 0.6000 - val_loss: 0.7400
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.8235 - loss: 0.4628 - val_accuracy: 0.6000 - val_loss: 0.8287
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7825 - loss: 0.4760 - val_accuracy: 0.5667 - val_loss: 0.8120
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7550 - loss: 0.4845 - val_accuracy: 0.5667 - val_loss: 0.7278
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7605 - loss: 0.5231 - val_accuracy: 0.6333 - val_loss: 0.7802
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8068 - loss: 0.4709 - val_accuracy: 0.5500 - val_loss: 0.7935
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7879 - loss: 0.4806 - val_accuracy: 0.5833 - val_loss: 0.7777
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7963 - loss: 0.4513 - val_accuracy: 0.4833 - val_loss: 0.8837
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7272 - loss: 0.5813 - val_accuracy: 0.6167 - val_loss: 0.7422
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7974 - loss: 0.4504 - val_accuracy: 0.5500 - val_loss: 0.7327
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8340 - loss: 0.4360 - val_accuracy: 0.6000 - val_loss: 0.8401
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.8125 - loss: 0.4267 - val_accuracy: 0.5333 - val_loss: 0.9256
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7870 - loss: 0.4612 - val_accuracy: 0.5000 - val_loss: 0.8507
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7790 - loss: 0.4725 - val_accuracy: 0.6167 - val_loss: 0.8891
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8070 - loss: 0.4463 - val_accuracy: 0.5167 - val_loss: 0.8699
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8079 - loss: 0.4421 - val_accuracy: 0.5833 - val_loss: 0.8607
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8076 - loss: 0.4596 - val_accuracy: 0.5833 - val_loss: 0.8120
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8301 - loss: 0.4003 - val_accuracy: 0.6000 - val_loss: 0.8049
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8206 - loss: 0.4275 - val_accuracy: 0.6000 - val_loss: 0.8316
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7520 - loss: 0.5264 - val_accuracy: 0.6000 - val_loss: 0.8779
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8548 - loss: 0.3655 - val_accuracy: 0.6167 - val_loss: 0.9170
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.7601 - loss: 0.5360 - val_accuracy: 0.6167 - val_loss: 0.7179
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8294 - loss: 0.4475 - val_accuracy: 0.5667 - val_loss: 0.8145
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.8193 - loss: 0.4239 - val_accuracy: 0.5167 - val_loss: 0.9939
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7792 - loss: 0.4939 - val_accuracy: 0.5833 - val_loss: 0.9985
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8168 - loss: 0.4570 - val_accuracy: 0.6000 - val_loss: 0.8669
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8295 - loss: 0.4045 - val_accuracy: 0.5833 - val_loss: 0.8617
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8148 - loss: 0.4029 - val_accuracy: 0.6333 - val_loss: 0.8176
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 793ms/step
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58        26
#            1       0.68      0.68      0.68        34
#
#     accuracy                           0.63        60
#    macro avg       0.63      0.63      0.63        60
# weighted avg       0.63      0.63      0.63        60

# %% [markdown]
# ### Recurrent Neural Network (RNN)

# %% [markdown]
# An RNN model with three LSTM layers and dropout layers for regularization is defined.
# The model is designed for binary classification, with the final layer using a sigmoid activation function.This model aims to leverage the temporal dependencies in the weather data using LSTMs to improve the accuracy of rainfall predictions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau


df = pd.read_csv("/content/weather_data_preprocessed.csv") 


df["date"] = pd.to_datetime(df["date"])
df["day_of_year"] = df["date"].dt.dayofyear
df["month"] = df["date"].dt.month
df["season"] = df["month"] % 12 // 3 + 1  


features = ["pressure", "avg_temperature", "avg_wind_speed", "cloud_cover", "day_of_year", "season"]
X = df[features]
y = df["rain_or_not"]


scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)


def create_sequences(data, labels, sequence_length=10):
    Xs, ys = [], []
    for i in range(len(data) - sequence_length):
        Xs.append(data[i : i + sequence_length])
        ys.append(labels[i + sequence_length])
    return np.array(Xs), np.array(ys)

sequence_length = 10
X_seq, y_seq = create_sequences(X_scaled, y.values, sequence_length)

X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42, stratify=y_seq)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42, stratify=y_train)

# Compute Class Weights
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_train), y=y_train)
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}

model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(sequence_length, X_train.shape[2])),
    Dropout(0.3),

    LSTM(64, return_sequences=True),
    Dropout(0.3),

    LSTM(32),
    Dropout(0.3),

    Dense(1, activation="sigmoid")  
])


model.compile(optimizer=Adam(learning_rate=0.001), loss="binary_crossentropy", metrics=["accuracy"])


lr_scheduler = ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.5, min_lr=1e-5)


history = model.fit(X_train, y_train, validation_data=(X_val, y_val),
                    epochs=100, batch_size=32, verbose=1, class_weight=class_weight_dict,
                    callbacks=[lr_scheduler])


his = pd.DataFrame(history.history)


plt.figure(figsize=(10,5))
sns.lineplot(data=his[["loss", "val_loss"]])
plt.title("Loss & Validation Loss")
plt.show()
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.4478 - loss: 0.7109 - val_accuracy: 0.5000 - val_loss: 0.6797 - learning_rate: 0.0010
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5874 - loss: 0.6889 - val_accuracy: 0.7083 - val_loss: 0.6359 - learning_rate: 0.0010
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6556 - loss: 0.6771 - val_accuracy: 0.7500 - val_loss: 0.6084 - learning_rate: 0.0010
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6456 - loss: 0.6431 - val_accuracy: 0.7500 - val_loss: 0.6015 - learning_rate: 0.0010
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6416 - loss: 0.6355 - val_accuracy: 0.7917 - val_loss: 0.5780 - learning_rate: 0.0010
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6705 - loss: 0.6332 - val_accuracy: 0.7083 - val_loss: 0.5925 - learning_rate: 0.0010
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6474 - loss: 0.6145 - val_accuracy: 0.7083 - val_loss: 0.5870 - learning_rate: 0.0010
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6658 - loss: 0.6434 - val_accuracy: 0.7083 - val_loss: 0.5832 - learning_rate: 0.0010
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6415 - loss: 0.6730 - val_accuracy: 0.7083 - val_loss: 0.5896 - learning_rate: 0.0010
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6755 - loss: 0.6555 - val_accuracy: 0.7083 - val_loss: 0.5906 - learning_rate: 0.0010
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6687 - loss: 0.6546 - val_accuracy: 0.7083 - val_loss: 0.5837 - learning_rate: 5.0000e-04
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6763 - loss: 0.6608 - val_accuracy: 0.7083 - val_loss: 0.5893 - learning_rate: 5.0000e-04
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6005 - loss: 0.6773 - val_accuracy: 0.7083 - val_loss: 0.5905 - learning_rate: 5.0000e-04
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6686 - loss: 0.6562 - val_accuracy: 0.7083 - val_loss: 0.5781 - learning_rate: 5.0000e-04
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6830 - loss: 0.6431 - val_accuracy: 0.6667 - val_loss: 0.5873 - learning_rate: 5.0000e-04
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6596 - loss: 0.6400 - val_accuracy: 0.7083 - val_loss: 0.5838 - learning_rate: 2.5000e-04
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6505 - loss: 0.6577 - val_accuracy: 0.7083 - val_loss: 0.5826 - learning_rate: 2.5000e-04
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6629 - loss: 0.6464 - val_accuracy: 0.7083 - val_loss: 0.5825 - learning_rate: 2.5000e-04
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6483 - loss: 0.6455 - val_accuracy: 0.7083 - val_loss: 0.5834 - learning_rate: 2.5000e-04
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6710 - loss: 0.6467 - val_accuracy: 0.6667 - val_loss: 0.5872 - learning_rate: 2.5000e-04
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6521 - loss: 0.6450 - val_accuracy: 0.6667 - val_loss: 0.5850 - learning_rate: 1.2500e-04
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6452 - loss: 0.6320 - val_accuracy: 0.7083 - val_loss: 0.5807 - learning_rate: 1.2500e-04
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6419 - loss: 0.6435 - val_accuracy: 0.7083 - val_loss: 0.5795 - learning_rate: 1.2500e-04
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.6510 - loss: 0.6427 - val_accuracy: 0.7083 - val_loss: 0.5795 - learning_rate: 1.2500e-04
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.6916 - loss: 0.6338 - val_accuracy: 0.7083 - val_loss: 0.5790 - learning_rate: 1.2500e-04
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6764 - loss: 0.6386 - val_accuracy: 0.7083 - val_loss: 0.5794 - learning_rate: 6.2500e-05
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6811 - loss: 0.6232 - val_accuracy: 0.7083 - val_loss: 0.5792 - learning_rate: 6.2500e-05
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6785 - loss: 0.6252 - val_accuracy: 0.7083 - val_loss: 0.5809 - learning_rate: 6.2500e-05
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6421 - loss: 0.6257 - val_accuracy: 0.6667 - val_loss: 0.5818 - learning_rate: 6.2500e-05
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6457 - loss: 0.6456 - val_accuracy: 0.7083 - val_loss: 0.5810 - learning_rate: 6.2500e-05
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6320 - loss: 0.6726 - val_accuracy: 0.6667 - val_loss: 0.5817 - learning_rate: 3.1250e-05
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6668 - loss: 0.6314 - val_accuracy: 0.7083 - val_loss: 0.5808 - learning_rate: 3.1250e-05
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6425 - loss: 0.6673 - val_accuracy: 0.6667 - val_loss: 0.5813 - learning_rate: 3.1250e-05
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6380 - loss: 0.6347 - val_accuracy: 0.6667 - val_loss: 0.5811 - learning_rate: 3.1250e-05
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6603 - loss: 0.6418 - val_accuracy: 0.6667 - val_loss: 0.5811 - learning_rate: 3.1250e-05
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6526 - loss: 0.6472 - val_accuracy: 0.6667 - val_loss: 0.5811 - learning_rate: 1.5625e-05
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6135 - loss: 0.6609 - val_accuracy: 0.6667 - val_loss: 0.5811 - learning_rate: 1.5625e-05
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6407 - loss: 0.6578 - val_accuracy: 0.6667 - val_loss: 0.5813 - learning_rate: 1.5625e-05
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6061 - loss: 0.6617 - val_accuracy: 0.6667 - val_loss: 0.5815 - learning_rate: 1.5625e-05
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6406 - loss: 0.6584 - val_accuracy: 0.6667 - val_loss: 0.5813 - learning_rate: 1.5625e-05
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6324 - loss: 0.6237 - val_accuracy: 0.6667 - val_loss: 0.5811 - learning_rate: 1.0000e-05
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6496 - loss: 0.6558 - val_accuracy: 0.6667 - val_loss: 0.5816 - learning_rate: 1.0000e-05
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6618 - loss: 0.6476 - val_accuracy: 0.6667 - val_loss: 0.5815 - learning_rate: 1.0000e-05
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6797 - loss: 0.6314 - val_accuracy: 0.6667 - val_loss: 0.5814 - learning_rate: 1.0000e-05
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6837 - loss: 0.6297 - val_accuracy: 0.6667 - val_loss: 0.5814 - learning_rate: 1.0000e-05
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6372 - loss: 0.6453 - val_accuracy: 0.6667 - val_loss: 0.5815 - learning_rate: 1.0000e-05
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6597 - loss: 0.6122 - val_accuracy: 0.6667 - val_loss: 0.5813 - learning_rate: 1.0000e-05
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6407 - loss: 0.6598 - val_accuracy: 0.6667 - val_loss: 0.5814 - learning_rate: 1.0000e-05
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6604 - loss: 0.6275 - val_accuracy: 0.6667 - val_loss: 0.5812 - learning_rate: 1.0000e-05
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6229 - loss: 0.6582 - val_accuracy: 0.6667 - val_loss: 0.5814 - learning_rate: 1.0000e-05
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7039 - loss: 0.6143 - val_accuracy: 0.6667 - val_loss: 0.5812 - learning_rate: 1.0000e-05
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6400 - loss: 0.6391 - val_accuracy: 0.6667 - val_loss: 0.5812 - learning_rate: 1.0000e-05
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6141 - loss: 0.6700 - val_accuracy: 0.6667 - val_loss: 0.5813 - learning_rate: 1.0000e-05
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6264 - loss: 0.6490 - val_accuracy: 0.6667 - val_loss: 0.5811 - learning_rate: 1.0000e-05
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6290 - loss: 0.6550 - val_accuracy: 0.6667 - val_loss: 0.5811 - learning_rate: 1.0000e-05
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6611 - loss: 0.6215 - val_accuracy: 0.6667 - val_loss: 0.5810 - learning_rate: 1.0000e-05
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6333 - loss: 0.6697 - val_accuracy: 0.6667 - val_loss: 0.5812 - learning_rate: 1.0000e-05
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6224 - loss: 0.6453 - val_accuracy: 0.6667 - val_loss: 0.5813 - learning_rate: 1.0000e-05
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6532 - loss: 0.6395 - val_accuracy: 0.6667 - val_loss: 0.5812 - learning_rate: 1.0000e-05
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6182 - loss: 0.6498 - val_accuracy: 0.6667 - val_loss: 0.5812 - learning_rate: 1.0000e-05
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6330 - loss: 0.6628 - val_accuracy: 0.6667 - val_loss: 0.5812 - learning_rate: 1.0000e-05
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.6592 - loss: 0.6360 - val_accuracy: 0.6667 - val_loss: 0.5810 - learning_rate: 1.0000e-05
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6720 - loss: 0.6434 - val_accuracy: 0.6667 - val_loss: 0.5812 - learning_rate: 1.0000e-05
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.6529 - loss: 0.6371 - val_accuracy: 0.6667 - val_loss: 0.5813 - learning_rate: 1.0000e-05
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6732 - loss: 0.6227 - val_accuracy: 0.6667 - val_loss: 0.5814 - learning_rate: 1.0000e-05
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6274 - loss: 0.6636 - val_accuracy: 0.6667 - val_loss: 0.5815 - learning_rate: 1.0000e-05
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6533 - loss: 0.6588 - val_accuracy: 0.6667 - val_loss: 0.5815 - learning_rate: 1.0000e-05
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.6500 - loss: 0.6205 - val_accuracy: 0.6667 - val_loss: 0.5813 - learning_rate: 1.0000e-05
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6188 - loss: 0.6441 - val_accuracy: 0.6667 - val_loss: 0.5814 - learning_rate: 1.0000e-05
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6203 - loss: 0.6730 - val_accuracy: 0.6667 - val_loss: 0.5817 - learning_rate: 1.0000e-05
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6531 - loss: 0.6304 - val_accuracy: 0.6667 - val_loss: 0.5816 - learning_rate: 1.0000e-05
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6195 - loss: 0.6875 - val_accuracy: 0.6667 - val_loss: 0.5820 - learning_rate: 1.0000e-05
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6024 - loss: 0.6677 - val_accuracy: 0.6667 - val_loss: 0.5821 - learning_rate: 1.0000e-05
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6386 - loss: 0.6681 - val_accuracy: 0.6667 - val_loss: 0.5821 - learning_rate: 1.0000e-05
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6286 - loss: 0.6701 - val_accuracy: 0.6667 - val_loss: 0.5823 - learning_rate: 1.0000e-05
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6499 - loss: 0.6193 - val_accuracy: 0.6667 - val_loss: 0.5818 - learning_rate: 1.0000e-05
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.6631 - loss: 0.6365 - val_accuracy: 0.6667 - val_loss: 0.5817 - learning_rate: 1.0000e-05
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6330 - loss: 0.6449 - val_accuracy: 0.6667 - val_loss: 0.5818 - learning_rate: 1.0000e-05
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6324 - loss: 0.6417 - val_accuracy: 0.6667 - val_loss: 0.5822 - learning_rate: 1.0000e-05
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6311 - loss: 0.6708 - val_accuracy: 0.6667 - val_loss: 0.5824 - learning_rate: 1.0000e-05
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6333 - loss: 0.6457 - val_accuracy: 0.6667 - val_loss: 0.5823 - learning_rate: 1.0000e-05
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6521 - loss: 0.6293 - val_accuracy: 0.6667 - val_loss: 0.5822 - learning_rate: 1.0000e-05
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6390 - loss: 0.6601 - val_accuracy: 0.6667 - val_loss: 0.5824 - learning_rate: 1.0000e-05
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6234 - loss: 0.6548 - val_accuracy: 0.6667 - val_loss: 0.5823 - learning_rate: 1.0000e-05
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6720 - loss: 0.6292 - val_accuracy: 0.6667 - val_loss: 0.5819 - learning_rate: 1.0000e-05
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6256 - loss: 0.6654 - val_accuracy: 0.6667 - val_loss: 0.5820 - learning_rate: 1.0000e-05
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6757 - loss: 0.6397 - val_accuracy: 0.6667 - val_loss: 0.5820 - learning_rate: 1.0000e-05
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6674 - loss: 0.6268 - val_accuracy: 0.6667 - val_loss: 0.5819 - learning_rate: 1.0000e-05
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6907 - loss: 0.6531 - val_accuracy: 0.6667 - val_loss: 0.5822 - learning_rate: 1.0000e-05
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6315 - loss: 0.6397 - val_accuracy: 0.6667 - val_loss: 0.5821 - learning_rate: 1.0000e-05
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6365 - loss: 0.6471 - val_accuracy: 0.6667 - val_loss: 0.5820 - learning_rate: 1.0000e-05
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6787 - loss: 0.6091 - val_accuracy: 0.6667 - val_loss: 0.5817 - learning_rate: 1.0000e-05
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6752 - loss: 0.6251 - val_accuracy: 0.6667 - val_loss: 0.5818 - learning_rate: 1.0000e-05
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6367 - loss: 0.6660 - val_accuracy: 0.6667 - val_loss: 0.5820 - learning_rate: 1.0000e-05
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6028 - loss: 0.6784 - val_accuracy: 0.6667 - val_loss: 0.5820 - learning_rate: 1.0000e-05
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6287 - loss: 0.6366 - val_accuracy: 0.6667 - val_loss: 0.5819 - learning_rate: 1.0000e-05
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6558 - loss: 0.6525 - val_accuracy: 0.6667 - val_loss: 0.5819 - learning_rate: 1.0000e-05
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.6483 - loss: 0.6565 - val_accuracy: 0.6667 - val_loss: 0.5818 - learning_rate: 1.0000e-05
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.6359 - loss: 0.6498 - val_accuracy: 0.6667 - val_loss: 0.5817 - learning_rate: 1.0000e-05
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5829 - loss: 0.6630 - val_accuracy: 0.6667 - val_loss: 0.5816 - learning_rate: 1.0000e-05

# %%
from sklearn.metrics import classification_report, confusion_matrix


test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")


y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)  # Convert probabilities to binary labels


print("\nClassification Report:")
print(classification_report(y_test, y_pred))


cm = confusion_matrix(y_test, y_pred)


plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["No Rain", "Rain"], yticklabels=["No Rain", "Rain"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Test Loss: 0.6613
# Test Accuracy: 0.6230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 458ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.61      0.55        23
#            1       0.73      0.63      0.68        38
#
#     accuracy                           0.62        61
#    macro avg       0.61      0.62      0.61        61
# weighted avg       0.64      0.62      0.63        61

# %% [markdown]
# # Hyperparameter Optimization

# %% [markdown]
# ### Best model selected is the ensemble model with SMOTEENN

# %% [markdown]
# GridSearchCV is used to perform an exhaustive search over the specified parameter grid for the ensemble model.
# The GridSearchCV object is instantiated with the ensemble model, the hyperparameter grid, 3-fold cross-validation, accuracy as the scoring metric, and it's set to use all available CPU cores (n_jobs=-1).
# The fit method is called on the GridSearchCV object with the training data to perform the grid search and hyperparameter tuning.

# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from imblearn.combine import SMOTEENN

# Suppress warnings
warnings.filterwarnings("ignore")


df = pd.read_csv('/content/weather_data_preprocessed.csv')
df = df.drop(columns=['date', 'humidity'])


X = df.drop(columns=['rain_or_not'])
y = df['rain_or_not']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

smote_enn = SMOTEENN(random_state=42)
X_resampled, y_resampled = smote_enn.fit_resample(X_scaled, y)


X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

rf = RandomForestClassifier(random_state=42)
xgb_model = xgb.XGBClassifier(eval_metric='logloss', random_state=42)
dt = DecisionTreeClassifier(random_state=42)
lgbm_model = lgb.LGBMClassifier(random_state=42, verbosity=-1)

# Define hyperparameter grid for optimization
param_grid = {
    'RandomForest__n_estimators': [100, 200],
    'RandomForest__max_depth': [10, 20],
   # 'XGBoost__n_estimators': [100, 200],
   # 'XGBoost__learning_rate': [0.01, 0.1],
    'LightGBM__n_estimators': [100, 200],
    'LightGBM__learning_rate': [0.01, 0.1]
}

# Create an ensemble model using soft voting
ensemble_model = VotingClassifier(
    estimators=[
        ('RandomForest', rf),
       # ('XGBoost', xgb_model),
        #('DecisionTree', dt),
        ('LightGBM', lgbm_model)
    ],
    voting='soft'
)

# Hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(ensemble_model, param_grid, cv=3, scoring='accuracy', n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_

# Predictions
y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:, 1]

# Evaluation Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)

# Print best parameters & evaluation results
print("Best Parameters:", grid_search.best_params_)
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'ROC-AUC Score: {roc_auc:.4f}')
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best Parameters: {'LightGBM__learning_rate': 0.01, 'LightGBM__n_estimators': 200, 'RandomForest__max_depth': 10, 'RandomForest__n_estimators': 100}
# Accuracy: 0.8846
# Precision: 0.9091
# Recall: 0.8333
# F1 Score: 0.8696
# ROC-AUC Score: 0.9345

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import cross_val_predict

# Define base models
rf = RandomForestClassifier(n_estimators=100, random_state=42)
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
dt = DecisionTreeClassifier(random_state=42)
lgbm_model = lgb.LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42, verbosity=-1)

# Create an ensemble model using soft voting
ensemble_model = VotingClassifier(
    estimators=[
        ('RandomForest', rf),
        #('XGBoost', xgb_model),
        #('DecisionTree', dt),
        ('LightBGM', lgbm_model)
    ],
    voting='soft'
)

# Fit the ensemble model
ensemble_model.fit(X_resampled, y_resampled)

# Predict probabilities
probabilities = ensemble_model.predict_proba(X_resampled)

# Evaluate the ensemble model
print("Evaluating Ensemble Model")
evaluate_model_with_cv(ensemble_model, X_resampled, y_resampled)

# Example of how to access probabilities for the first sample
print("Probabilities for the first sample:", probabilities[0])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Evaluating Ensemble Model
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Model: VotingClassifier
# Cross-Validation Accuracy: 0.6944 (+/- 0.0271)
# Cross-Validation ROC AUC: 0.7418 (+/- 0.0327)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       198
#            1       0.99      1.00      1.00       198
#
#     accuracy                           1.00       396
#    macro avg       1.00      1.00      1.00       396
# weighted avg       1.00      1.00      1.00       396
#
# --------------------------------------------------
# Probabilities for the first sample: [0.1331319 0.8668681]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
